# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.datasets as sk_data
import sklearn.metrics as metrics
from sklearn import preprocessing
from scipy.cluster.hierarchy import dendrogram, linkage
import math
import json
import seaborn as sns
import collections
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import kneighbors_graph
from sklearn.cluster import KMeans
from sklearn import mixture

# %%
data=pd.read_csv('Brazilian Foreign-Born Estimates from ACS Data 2013-2015.csv')
data=data.iloc[2:]
new_header = data.iloc[0] #grab the first row for the header
data = data[1:] #take the data less the header row
data.columns = new_header #set the header row as the df header
data
# Out:
# 2                                                  NaN     NaN       NaN  \
# 3                                           Population    Est.   362,398
# 4                                                  NaN       %   100.00%
# 5                                           Age 0 to 4    Est.     3,155
# 6                                                  NaN       %     0.90%
# 7                                           Age 5 to 9    Est.     4,866
# 8                                                  NaN       %     1.30%
# 9                                         Age 10 to 14    Est.     7,445
# 10                                                 NaN       %     2.10%
# 11                                        Age 15 to 19    Est.    15,157
# 12                                                 NaN       %     4.20%
# 13                                        Age 20 to 24    Est.    26,740
# 14                                                 NaN       %     7.40%
# ...

# %%
data1=data
row1=data1.iloc[[2]]
row1
# Out:
# 2         NaN   NaN    NaN Alabama Alaska Arizona Arkansas California  \
# 5  Age 0 to 4  Est.  3,155       0      0      11        0        344
#
# 2 Colorado Connecticut   ...   South Dakota Tennessee Texas Utah Vermont  \
# 5        0           0   ...              0        34   145    0       0
#
# 2 Virginia Washington West Virginia Wisconsin Wyoming
# 5      166          0             0         0       0
#
# [1 rows x 54 columns]

# %%
# data2=data
# for index,row in data2.iterrows():
#     if pd.isnull(row[0]): continue
#     else:
#         for i in range(2,54):
#             row[i]=int(row[i].replace(',',''))
data
# Out:
# 2                                                  NaN     NaN       NaN  \
# 3                                           Population    Est.    362398
# 4                                                  NaN       %   100.00%
# 5                                           Age 0 to 4    Est.      3155
# 6                                                  NaN       %     0.90%
# 7                                           Age 5 to 9    Est.      4866
# 8                                                  NaN       %     1.30%
# 9                                         Age 10 to 14    Est.      7445
# 10                                                 NaN       %     2.10%
# 11                                        Age 15 to 19    Est.     15157
# 12                                                 NaN       %     4.20%
# 13                                        Age 20 to 24    Est.     26740
# 14                                                 NaN       %     7.40%
# ...

# %%
for index,row in data.iterrows():
    if pd.isnull(row[0]): continue
    else:
        if pd.isnull(row[2]): continue
        else:
            total=row[2]
            for i in range(3,54):
                if(not pd.isnull(row[i])):
                    per=row[i]/total
                    print(per)
                    row[i]=per
# Out:
# 0.002304096600974619
# 0.0008774882863591963
# 0.007439334654164758
# 0.0013603827835694457
# 0.10166446834695556
# 0.007745627735252402
# 0.04261888862521317
# 0.002168886141755749
# 0.004610952599076154
# 0.20115729115502845
# 0.02937930121027158
# 0.0028173444665809413
# 0.0011423904105431046
# 0.014384737222611604
# 0.006255553286717918
# 0.0019619313572370707
# 0.002563479930904696
# 0.00269593099299665
# 0.006639109487359201
# 0.0010375333197203075
# 0.01952825346718249
# 0.1688999387413838
# 0.011388031942781141
# 0.006688778635643685
# 0.0009795859800550775
# 0.005060734330763415
# 0.0008278191380747135
# 0.0009713077886743304
# 0.01033946103455317
# 0.006542530587917152
# 0.08373942461051109
# 0.0028642542177385083
# 0.070778536305388
# 0.015209796963559402
# 0.001826720898018201
# 0.012265520229140337
# 0.0017080668215608253
# 0.00564296712454263
# 0.02335553728221458
# 0.003454765202898471
# 0.008485146165265812
# 0.00023454875578783548
# 0.004591636819187744
# ...

# %%
data
# Out:
# 2                                                  NaN     NaN       NaN  \
# 3                                           Population    Est.    362398
# 4                                                  NaN       %   100.00%
# 5                                           Age 0 to 4    Est.      3155
# 6                                                  NaN       %     0.90%
# 7                                           Age 5 to 9    Est.      4866
# 8                                                  NaN       %     1.30%
# 9                                         Age 10 to 14    Est.      7445
# 10                                                 NaN       %     2.10%
# 11                                        Age 15 to 19    Est.     15157
# 12                                                 NaN       %     4.20%
# 13                                        Age 20 to 24    Est.     26740
# 14                                                 NaN       %     7.40%
# ...

# %%
data.to_csv('data_with_percentage.csv')
